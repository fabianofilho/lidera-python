# %% [markdown]
# ##**Paradigmas da Programação**

# %% [markdown]
# ###**Programação estruturada**

# %% [markdown]
# ####Programação Estruturada (PE) é um padrão ou paradigma de programação da engenharia de softwares, com ênfase em sequência, decisão e, iteração (sub-rotinas, laços de repetição, condicionais e, estruturas em bloco)
#
# ####Este paradigma é normalmente formado por código em um único bloco

# %% [markdown]
# ![alt text](https://cic.unb.br/~jhcf/MyBooks/itjava/JavaBook1996/aula1/figuras/progestr.gif)

# %% [markdown]
# ###**Programação orientada a objeto**

# %% [markdown]
# ####Programação Orientada a Objetos (também conhecida pela sua sigla POO) é um modelo de análise, projeto e programação de software baseado na composição e interação entre diversas unidades chamadas de 'objetos'.
#
# ####Os programas são arquitetados através de objetos que interagem entre si. Dentre as várias abordagens da POO, as baseadas em classes são as mais comuns: objetos são instâncias de classes, o que em geral também define o tipo do objeto. Cada classe determina o comportamento (definido nos métodos) e estados possíveis (atributos) de seus objetos

# %% [markdown]
# ![alt text](https://www.alura.com.br/artigos/assets/poo-programacao-orientada-a-objetos/class-analogy.png)

# %% [markdown]
# ![alt text](https://www.alura.com.br/artigos/assets/poo-programacao-orientada-a-objetos/oop-car-methods-and-attributes.png)

# %% [markdown]
# ###**Programação funcional**

# %% [markdown]
# ####Em ciência da computação, programação funcional é um paradigma de programação que trata a computação como uma avaliação de funções matemáticas e que evita estados ou dados mutáveis. Ela enfatiza a aplicação de funções, em contraste da programação imperativa, que enfatiza mudanças no estado do programa
#
# ####Uma função, neste sentido, pode ter ou não ter parâmetros e um simples valor de retorno. Os parâmetros são os valores de entrada da função, e o valor de retorno é o resultado da função.

# %% [markdown]
# ![alt text](https://www.lambda3.com.br/wp-content/uploads//2017/01/map-filter-reduce-in-emoji-1.png)

# %% [markdown]
# ##**Curso Python aula 4 - Bibliotecas**

# %%
lista = []
lista
# Out:
# []

# %%
lista.append(3)
lista.append(5)
lista.append(6)
lista
# Out:
# [3, 5, 6, 3, 5, 6, 3, 5, 6]

# %%
lista.pop(0)
# Out:
# 3

# %%
lista.remove(3)

# %%
lista
# Out:
# [5, 6, 3, 5, 6, 3, 5, 6]

# %%
lista = [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
lista.sort(reverse=True)
lista
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
string = 'Hello, this is a example string!'
type(string)
string = string.split()
string
# Out:
# ['Hello,', 'this', 'is', 'a', 'example', 'string!']

# %%
''.join(string)
# Out:
# 'Hello,thisisaexamplestring!'

# %%
string = string.upper()

# %%
string.lower()
# Out:
# 'hello, this is a example string!'

# %%
string
# Out:
# 'HELLO, THIS IS A EXAMPLE STRING!'

# %% [markdown]
# ###**Funções *lambda*, *filter* e *map*.**

# %%
lista1 = [1, 2, 3]
m = map(lambda x: x**2, lista1)
list(m)
# Out:
# [1, 4, 9]

# %%
list(filter(lambda x: x > 1, lista1))
# Out:
# [2, 3]

# %%
def quad(x):
    return x**2

list(map(quad, lista1))
# Out:
# [1, 4, 9]

# %%
aulas = ({'aula': 1, 'duracao': 2.0},
         {'aula': 2, 'duracao': 1.5,},
         {'aula': 3, 'duracao': 0.75})

# %%
m = map(lambda i: i['duracao'] / 2, aulas)
l = list(m)

# %%
f = filter(lambda i: i >= 1, l)
list(f)
# Out:
# [1.0]

# %% [markdown]
# ##**Curso Python aula 4 - Visão geral do matplotlib**

# %% [markdown]
# ####**Matplotlib é uma biblioteca de software para criação de gráficos e visualizações de dados em geral, feita para a da linguagem de programação Python e sua extensão de matemática NumPy.**

# %% [markdown]
# ####Documentação: https://matplotlib.org/index.html

# %% [markdown]
# ![alt text](https://minerandodados.com.br/wp-content/uploads/2017/12/matplotlib-1.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Criar array com linspace, cria um array que anda conforme especificado**

# %%
x = np.linspace(0, 5, 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x * x
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#forma funcional do matplotlib
plt.plot(x, y, 'r.-')
plt.xlabel('Tempo')
plt.ylabel('R$')
plt.title('Grafico y(x)')
# Out:
# Text(0.5, 1.0, 'Grafico y(x)')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r-')
plt.xlabel('eixo_x')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g--')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, 'purple')
ax.plot(x, x**4, 'g-.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Grafico')
# Out:
# Text(0.5, 1.0, 'Grafico')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(y, x, 'r--')
ax2.plot(x, y, 'b-.')
ax1.set_title('Grafico 1')
ax2.set_title('Grafico 2')
ax1.plot(x, x**4)
ax2.plot(x, np.log(x**4), 'g')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y, 'r', label='x ao quadrado')
ax.plot(y, x, 'b--', label='raiz de x')
ax.set_title('Grafico Y²')
ax.legend(loc=0)

# %%
fig.savefig('image.png')

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.plot(x, x**2, color='r', linewidth=10, alpha=0.4)
ax.plot(x, x**3)

ax.set_xlim([0, 2])
ax.set_ylim([0, 5])
# Out:
# (0.0, 5.0)

# %% [markdown]
# ###**Outros tipos de grafico**

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.scatter(x, y)

# %%
plt.hist(x,y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <a list of 10 Patch objects>)
