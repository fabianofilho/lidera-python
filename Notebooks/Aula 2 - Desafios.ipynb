# %% [markdown]
# **Desafio 1**
#
# Tendo ciência da frase:
#
# *Lorem ipsum dolor sit amet, consectetur adipiscing elit. Pellentesque quis pharetra quam. Suspendisse semper metus purus, sed finibus metus sollicitudin at. Aliquam congue venenatis porta. Nunc augue purus, pellentesque quis odio sit amet, egestas dictum est. Duis a tincidunt diam. Donec non accumsan ipsum, non rutrum enim. Aenean ut neque metus.*
#
# Sabendo que a equação de segundo grau é esta:
#
# ![alt text](https://s3.static.brasilescola.uol.com.br/img/2016/04/equacao-do-segundo-grau.jpg)
#
# E que a Fórmula de Bháskara para solução das raízes é esta:
#
# ![alt text](https://s2.static.brasilescola.uol.com.br/img/2016/04/formula-de-bhaskara-em-sua-forma-original.jpg)
#
# Faça o seguinte:
#
# Determine os **DOIS** valores da raíz da expressão de segundo grau cujos valores de **a**, **b** e **c** são:
#
# a = O índice da primeira ocorrência de "t" na frase
#
# b = O índice da primeira ocorrência de "a" na frase de trás para frente
#
# c = O tamanho da frase

# %% [markdown]
# **Desafio 2**
#
# Dada as listas:
#
# lista1 = [20, 34, 23, 2, 45]
#
# lista 2 = [33, 67, 83, 29, 40]
#
# Coloque a lista1 em ordem decrescente e a lista2 em ordem crescente.
#
# De forma manual faça uma lista de pares chave-valor de tuplas, onde:
#
# Chave = O algarismo do binário do item da lista1
#
# Valor = A soma dos algarismos dos binários dos itens da lista 1 e da lista2 relativos a mesma posição
#
# A partir disso crie um dicionário e retorne o valor da chave = "10"

# %% [markdown]
# **Desafio 3**
#
# Ordene o texto, retornem os indexs das primeiras ocorrências das letra "a", "e", "i", "o", "u" e "!" na variável "texto" em uma única variável (variável x). Após isso faça as seguintes operações:
#
# (1) - Faça uma adição da variável por ela mesma
# (2) - Faça uma exponenciação da variável por ela mesma
# (3) - Encontre o módulo do valor dela pelo número ao contrário dela mesma
#
# Depois faça:
#
# (2) - (1) + (3)

# %%
texto = "Olá Lidera. Eu estou feliz em tê-los conosco!"
# Out:
# 975181344
