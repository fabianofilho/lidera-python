# %% [markdown]
# #**Análise de Dados no Python com a biblioteca Pandas e Seaborn - Exercícios**

# %%
#colab import
#selecione o arquivo que disponibilizamos "iris.csv" e ele será gravado no colab
from google.colab import files
import os
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94e9f08a-61ad-4e9b-85c1-08c761536e21" name="files[]" multiple disabled />
#      <output id="result-94e9f08a-61ad-4e9b-85c1-08c761536e21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %% [markdown]
# ##**Importe o pandas como pd e numpy como np, o matplotlib.pyplot como plt e o seaborn como sns**

# %%
# %matplotlib inline

# %% [markdown]
# ##**Leia o arquivo "iris.csv" com a função pd.read_csv e atribua a uma variavel com o nome iris**

# %% [markdown]
# ##**Mostre o cabeçalho do DataFrame com a função head**

# %%
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ##**Analise as informações do DataFrame com a função info**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ##**Veja os detalhes estatísticos do Dataframe com a função describe**

# %%
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ##**Crie uma nova feature chamada "total.length" que será a soma das features "sepal.length" e "petal.length", depois vizualize o cabeçalho do DataFrame**

# %%
# Out:
# 0       6.5
# 1       6.3
# 2       6.0
# 3       6.1
# 4       6.4
#        ...
# 145    11.9
# 146    11.3
# 147    11.7
# 148    11.6
# 149    11.0
# Name: total.length, Length: 150, dtype: float64

# %%
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  total.length
# 0           5.1          3.5           1.4          0.2  Setosa           6.5
# 1           4.9          3.0           1.4          0.2  Setosa           6.3
# 2           4.7          3.2           1.3          0.2  Setosa           6.0
# 3           4.6          3.1           1.5          0.2  Setosa           6.1
# 4           5.0          3.6           1.4          0.2  Setosa           6.4

# %% [markdown]
# ##**Faça o mesmo com as colunas width, criando uma nova feature chamada "total.width"**

# %%
# Out:
# 0      3.7
# 1      3.2
# 2      3.4
# 3      3.3
# 4      3.8
#       ...
# 145    5.3
# 146    4.4
# 147    5.0
# 148    5.7
# 149    4.8
# Name: total.width, Length: 150, dtype: float64

# %%
# Out:
#    sepal.length  sepal.width  petal.length  ...  variety total.length  total.width
# 0           5.1          3.5           1.4  ...   Setosa          6.5          3.7
# 1           4.9          3.0           1.4  ...   Setosa          6.3          3.2
# 2           4.7          3.2           1.3  ...   Setosa          6.0          3.4
# 3           4.6          3.1           1.5  ...   Setosa          6.1          3.3
# 4           5.0          3.6           1.4  ...   Setosa          6.4          3.8
#
# [5 rows x 7 columns]

# %% [markdown]
# ##**Mostre um DataFrame contendo apenas as plantas que possuem "total.lenght" maior que 14**

# %%
# Out:
#      sepal.length  sepal.width  ...  total.length  total.width
# 105           7.6          3.0  ...          14.2          5.1
# 117           7.7          3.8  ...          14.4          6.0
# 118           7.7          2.6  ...          14.6          4.9
# 122           7.7          2.8  ...          14.4          4.8
# 131           7.9          3.8  ...          14.3          5.8
#
# [5 rows x 7 columns]

# %% [markdown]
# ##**Mostre apenas a variedade das plantas em que "total.width" é maior ou igual a 5.5**

# %%
# Out:
# 100    Virginica
# 109    Virginica
# 115    Virginica
# 117    Virginica
# 120    Virginica
# 131    Virginica
# 136    Virginica
# 140    Virginica
# 143    Virginica
# 144    Virginica
# 148    Virginica
# Name: variety, dtype: object

# %% [markdown]
# ##**Plote um grafico de histograma da coluna "sepal.length" usando o pandas e depois faça o mesmo usando o seaborn com o distplot**

# %% [markdown]
# ##**Faça um pairplot do dataset, definindo o "hue" como a variedade da planta**

# %% [markdown]
# ##**Faça um jointplot de quaisquer duas variaveis que você queira (experimente mudar o atributo "kind" da função)**

# %% [markdown]
# ##**Tente observar qual variedade de planta possui maior comprimento total, utilizando um barplot**

# %% [markdown]
# ##**Faça o mesmo para observar qual variedade tem maior largura**

# %% [markdown]
# ##**Crie uma variavel que mede a correlação entre as features, depois crie um heatmap dessa variavel. Defina annot como verdadeiro**

# %% [markdown]
# ##**Qual conclusão voce consegue tirar sobre a relação entre as colunas do dataset, após manipular e visualizar os dados?**
